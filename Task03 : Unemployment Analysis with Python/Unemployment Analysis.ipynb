# %% [markdown]
# **Importing Libraries:**

# %%
#importing libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# **Creating Data Frame**

# %%
df = pd.read_csv("Unemployment in India.csv")

# %% [markdown]
# **Exploring the Dataset**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 740 entries, 0 to 739
# Data columns (total 7 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    740 non-null    object
#  1    Date                                     740 non-null    object
#  2    Frequency                                740 non-null    object
#  3    Estimated Unemployment Rate (%)          740 non-null    float64
#  4    Estimated Employed                       740 non-null    int64
#  5    Estimated Labour Participation Rate (%)  740 non-null    float64
#  6   Area                                      740 non-null    object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 40.6+ KB

# %%
print("Column Headings : \n\n",df.columns)
# Out:
# Column Headings :
#
#  Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Area'],
#       dtype='object')

# %% [markdown]
# **Checking Of Missing Values**

# %%
df.describe()
# Out:
#         Estimated Unemployment Rate (%)   Estimated Employed  \
# count                        740.000000         7.400000e+02
# mean                          11.787946         7.204460e+06
# std                           10.721298         8.087988e+06
# min                            0.000000         4.942000e+04
# 25%                            4.657500         1.190404e+06
# 50%                            8.350000         4.744178e+06
# 75%                           15.887500         1.127549e+07
# max                           76.740000         4.577751e+07
#
#         Estimated Labour Participation Rate (%)
# count                                740.000000
# mean                                  42.630122
# std                                    8.111094
# min                                   13.330000
# 25%                                   38.062500
# 50%                                   41.160000
# 75%                                   45.505000
# ...

# %%
round(df.describe().T)
# Out:
#                                           count       mean        std  \
#  Estimated Unemployment Rate (%)          740.0       12.0       11.0
#  Estimated Employed                       740.0  7204460.0  8087988.0
#  Estimated Labour Participation Rate (%)  740.0       43.0        8.0
#
#                                               min        25%        50%  \
#  Estimated Unemployment Rate (%)              0.0        5.0        8.0
#  Estimated Employed                       49420.0  1190404.0  4744178.0
#  Estimated Labour Participation Rate (%)     13.0       38.0       41.0
#
#                                                  75%         max
#  Estimated Unemployment Rate (%)                16.0        77.0
#  Estimated Employed                       11275490.0  45777509.0
#  Estimated Labour Participation Rate (%)        46.0        73.0

# %% [markdown]
# **Observation:- Average unemployment rate in India was 12% in 2020**

# %%
print("Number of Rows and Columns",df.shape)
# Out:
# Number of Rows and Columns (740, 7)

# %%
df.head()
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1  Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2  Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3  Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4  Andhra Pradesh   30-09-2019    Monthly                              5.17
#
#     Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0             11999139                                     43.24  Rural
# 1             11755881                                     42.05  Rural
# 2             12086707                                     43.50  Rural
# 3             12285693                                     43.97  Rural
# 4             12256762                                     44.68  Rural

# %%
df.columns
# Out:
# Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Area'],
#       dtype='object')

# %%
#Checking Of Missing Values
df.isnull().sum()
# Out:
# Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Area                                        0
# dtype: int64

# %%
#Cheking number of states in dataset
X=df['Region']
X.unique()
# Out:
# array(['Andhra Pradesh', 'Assam', 'Bihar', 'Chhattisgarh', 'Delhi', 'Goa',
#        'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir',
#        'Jharkhand', 'Karnataka', 'Kerala', 'Madhya Pradesh',
#        'Maharashtra', 'Meghalaya', 'Odisha', 'Puducherry', 'Punjab',
#        'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura',
#        'Uttar Pradesh', 'Uttarakhand', 'West Bengal', 'Chandigarh'],
#       dtype=object)

# %%
df.Region.value_counts()# counting values of each region
# Out:
# Andhra Pradesh      28
# Kerala              28
# West Bengal         28
# Uttar Pradesh       28
# Tripura             28
# Telangana           28
# Tamil Nadu          28
# Rajasthan           28
# Punjab              28
# Odisha              28
# Madhya Pradesh      28
# Maharashtra         28
# Karnataka           28
# Jharkhand           28
# Himachal Pradesh    28
# Haryana             28
# Gujarat             28
# Delhi               28
# Chhattisgarh        28
# Bihar               28
# Meghalaya           27
# Uttarakhand         27
# Assam               26
# Puducherry          26
# Goa                 24
# Jammu & Kashmir     21
# Sikkim              17
# Chandigarh          12
# Name: Region, dtype: int64

# %%
TotalStates = X.nunique()
print("Total Number of States:",TotalStates)
# Out:
# Total Number of States: 28

# %%
df = df.dropna()# droping null values

# %%
#Checking Of Missing Values
df.isnull().sum()
# Out:
# Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Area                                        0
# dtype: int64

# %%
#Check Unique values in the column Frequency
Frequency = df[' Frequency']
UniqueFrequency = Frequency.unique()
TotalFrequency = Frequency.nunique()
print("Unique Frequencies:",UniqueFrequency,"\nTotal Frequencies:",TotalFrequency)
# Out:
# Unique Frequencies: [' Monthly' 'Monthly']
# Total Frequencies: 2

# %% [markdown]
# Here the Frequency column had a space in the begining, instead of 'Frequency' its ' Frequency'<br>
# And also<br>
# It has 2 unique values which are essentially same<br>
# Since this column has only single value it doesn't make sense to keep it in the dataset occupying space, we should drop it!

# %%
#Check Unique values in the column Area
Area = df['Area']
UniqueArea = Area.unique()
TotalArea = Area.nunique()
print("Unique Frequencies:",UniqueArea,"\nTotal Frequencies:",TotalArea)
# Out:
# Unique Frequencies: ['Rural' 'Urban']
# Total Frequencies: 2

# %%
#Displaying : Estimated Unemployment Rate (%)
df.iloc[:,3]
# Out:
# 0       3.65
# 1       3.05
# 2       3.75
# 3       3.32
# 4       5.17
#        ...
# 735     7.55
# 736     6.67
# 737    15.63
# 738    15.22
# 739     9.86
# Name:  Estimated Unemployment Rate (%), Length: 740, dtype: float64

# %%
print("Column Headings : \n\n", df.columns)
# Out:
# Column Headings :
#
#  Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Area'],
#       dtype='object')

# %% [markdown]
# Since the Area column contains 2 unique values we cannot drop it

# %% [markdown]
# To select a single column, we can: df.iloc[:, 3]
# <br>
# This returns 4th column as a Pandas Series:

# %% [markdown]
# ### Visualization

# %%
import matplotlib.pyplot as plt

# %%
y=df['Region']
 
# getting values against each value of y
x=df[' Estimated Labour Participation Rate (%)']
plt.barh(y, x,)
 
# labeling data
plt.xlabel('Estimated Labour Participation Rate (%)')
plt.ylabel("States")
plt.title("Impact of Lockdown on employement across state")

plt.rcParams['figure.figsize'] = (20, 10.0)
plt.style.use('ggplot')

plt.show()

# %%
UnempRate = df[' Estimated Unemployment Rate (%)']
Region = df['Region']

# Create the bar plot
plt.bar(Region, UnempRate)

# Add a title and axis labels
plt.title('Region Vs Unemployement')
plt.xlabel('Region')
plt.ylabel('UnempRate')

plt.xticks(rotation=90)
plt.figure(figsize=(80, 80)) # increasing size for better visibility

# Show the plot
plt.show()

# %%
Heat_maps = df[['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
       ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
       'Area']]

Heat_maps = Heat_maps.corr()

plt.figure(figsize=(10,6))
sns.set_context('notebook',font_scale=1)
sns.heatmap(Heat_maps, annot=True,cmap="YlGnBu");

# %%
#Top estimated employed Regions 

Make_total = df.pivot_table(' Estimated Employed',index=['Region'],aggfunc='mean')
Topstate = Make_total.sort_values(by=' Estimated Employed',ascending=False)[:47]
print("Top estimated employed Regions By region :\n\n", Topstate)
# Out:
# Top estimated employed Regions By region :
#
#                     Estimated Employed
# Region
# Uttar Pradesh            2.809483e+07
# Maharashtra              1.999020e+07
# West Bengal              1.719854e+07
# Bihar                    1.236619e+07
# Tamil Nadu               1.226955e+07
# Gujarat                  1.140201e+07
# Madhya Pradesh           1.111548e+07
# Karnataka                1.066712e+07
# Rajasthan                1.004106e+07
# Andhra Pradesh           8.154093e+06
# Telangana                7.939663e+06
# Odisha                   6.545747e+06
# Assam                    5.354772e+06
# Punjab                   4.539362e+06
# Jharkhand                4.469240e+06
# Kerala                   4.425900e+06
# Chhattisgarh             4.303499e+06
# Haryana                  3.557072e+06
# Delhi                    2.627513e+06
# Jammu & Kashmir          1.799932e+06
# Uttarakhand              1.390228e+06
# Himachal Pradesh         1.059824e+06
# ...

# %%
g=sns.boxplot(data=df, x='Region', y=' Estimated Employed')
g.set_xticklabels(g.get_xticklabels(), rotation=85)
# Out:
# [Text(0, 0, 'Andhra Pradesh'),
#  Text(1, 0, 'Assam'),
#  Text(2, 0, 'Bihar'),
#  Text(3, 0, 'Chhattisgarh'),
#  Text(4, 0, 'Delhi'),
#  Text(5, 0, 'Goa'),
#  Text(6, 0, 'Gujarat'),
#  Text(7, 0, 'Haryana'),
#  Text(8, 0, 'Himachal Pradesh'),
#  Text(9, 0, 'Jammu & Kashmir'),
#  Text(10, 0, 'Jharkhand'),
#  Text(11, 0, 'Karnataka'),
#  Text(12, 0, 'Kerala'),
#  Text(13, 0, 'Madhya Pradesh'),
#  Text(14, 0, 'Maharashtra'),
#  Text(15, 0, 'Meghalaya'),
#  Text(16, 0, 'Odisha'),
#  Text(17, 0, 'Puducherry'),
#  Text(18, 0, 'Punjab'),
#  Text(19, 0, 'Rajasthan'),
#  Text(20, 0, 'Sikkim'),
#  Text(21, 0, 'Tamil Nadu'),
#  Text(22, 0, 'Telangana'),
#  Text(23, 0, 'Tripura'),
#  Text(24, 0, 'Uttar Pradesh'),
#  Text(25, 0, 'Uttarakhand'),
#  Text(26, 0, 'West Bengal'),
#  Text(27, 0, 'Chandigarh')]

# %%
# Sorting Unemployed Regions, top to bottom

Make_total = df.pivot_table(' Estimated Unemployment Rate (%)',index=['Region'],aggfunc='mean')
Topstate = Make_total.sort_values(by=' Estimated Unemployment Rate (%)',ascending=False)[:47]
print("Top estimated unemployed Regions By region :\n\n",topstate)
# Out:
# Top estimated unemployed Regions By region :
#
#                     Estimated Employed
# Region
# Uttar Pradesh            2.809483e+07
# Maharashtra              1.999020e+07
# West Bengal              1.719854e+07
# Bihar                    1.236619e+07
# Tamil Nadu               1.226955e+07
# Gujarat                  1.140201e+07
# Madhya Pradesh           1.111548e+07
# Karnataka                1.066712e+07
# Rajasthan                1.004106e+07
# Andhra Pradesh           8.154093e+06
# Telangana                7.939663e+06
# Odisha                   6.545747e+06
# Assam                    5.354772e+06
# Punjab                   4.539362e+06
# Jharkhand                4.469240e+06
# Kerala                   4.425900e+06
# Chhattisgarh             4.303499e+06
# Haryana                  3.557072e+06
# Delhi                    2.627513e+06
# Jammu & Kashmir          1.799932e+06
# Uttarakhand              1.390228e+06
# Himachal Pradesh         1.059824e+06
# ...

# %%
g=sns.boxplot(data=df, x='Region', y=' Estimated Unemployment Rate (%)')
g.set_xticklabels(g.get_xticklabels(), rotation=85)
# Out:
# [Text(0, 0, 'Andhra Pradesh'),
#  Text(1, 0, 'Assam'),
#  Text(2, 0, 'Bihar'),
#  Text(3, 0, 'Chhattisgarh'),
#  Text(4, 0, 'Delhi'),
#  Text(5, 0, 'Goa'),
#  Text(6, 0, 'Gujarat'),
#  Text(7, 0, 'Haryana'),
#  Text(8, 0, 'Himachal Pradesh'),
#  Text(9, 0, 'Jammu & Kashmir'),
#  Text(10, 0, 'Jharkhand'),
#  Text(11, 0, 'Karnataka'),
#  Text(12, 0, 'Kerala'),
#  Text(13, 0, 'Madhya Pradesh'),
#  Text(14, 0, 'Maharashtra'),
#  Text(15, 0, 'Meghalaya'),
#  Text(16, 0, 'Odisha'),
#  Text(17, 0, 'Puducherry'),
#  Text(18, 0, 'Punjab'),
#  Text(19, 0, 'Rajasthan'),
#  Text(20, 0, 'Sikkim'),
#  Text(21, 0, 'Tamil Nadu'),
#  Text(22, 0, 'Telangana'),
#  Text(23, 0, 'Tripura'),
#  Text(24, 0, 'Uttar Pradesh'),
#  Text(25, 0, 'Uttarakhand'),
#  Text(26, 0, 'West Bengal'),
#  Text(27, 0, 'Chandigarh')]

# %%
# Group data by region and date
grouped_df = df.groupby(["Region", " Date"]).sum()

# Create the stacked bar chart
fig, ax = plt.subplots(figsize=(15,8))
grouped_df[" Estimated Unemployment Rate (%)"].unstack().plot.bar(stacked=True, ax=ax)

# Label the plot
ax.set_ylabel(" Estimated Unemployment Rate (%)")
ax.set_xlabel(" Date")

# Arrange legend to the right upper corner
ax.legend(title="Date", loc='upper left', bbox_to_anchor=(1,1))

# Show plot
plt.show()
